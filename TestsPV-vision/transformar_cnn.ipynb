# %%
import numpy as np
import cv2 as cv
import os
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
import sys

from ipywidgets import interactive, widgets, Layout

# %matplotlib inline

# %%
from pv_vision.transform_crop.solarmodule import MaskModule

# %% [markdown]
# Proceso de un panel con un fondo complejo

# %%
# load the grayscale image
# create a raw module instance

img = cv.imread('/home/franklin/PVDefectDetect/EjemplosPV-vision/module_imgs/example_1.png', cv.IMREAD_UNCHANGED)
raw_module = MaskModule(img, 8, 16, 0) # 8 rows && 16 columns && 0 busbar
plt.imshow(raw_module.image, 'gray')

# %%
# Cargar la máscara predicha por UNet.
# Establece el parámetro "output=True" en load_mask() si deseas obtener la máscara como salida.

raw_module.load_mask('/home/franklin/PVDefectDetect/EjemplosPV-vision/module_imgs/example_1.png.json')
plt.imshow(raw_module.mask, 'gray')

# %%
# Búsqueda de esquinas 

def update_corner(mode):
    corners = raw_module.corner_detection_cont(output=True, mode=mode)
    x, y = zip(*corners)

    plt.figure(figsize=(8, 6))
    plt.imshow(raw_module.mask, 'gray')
    plt.scatter(x, y, c='r')

mode=widgets.IntSlider(value=4, min=0, max=4, step=1)
interactive(update_corner,
            mode=mode)
# Out:
# interactive(children=(IntSlider(value=4, description='mode', max=4), Output()), _dom_classes=('widget-interact…

# %%
# Transformación de perpectivas

# do perspective transform
img_transformed = raw_module.transform(width=600, height=300, img_only=True)
plt.imshow(img_transformed, 'gray')
# you can also set "img_only=False" to output a transformed module instance. This will be useful
# when you want to crop out single cells

# %%
# Ajuste para bordes verticales

def update_edges(vl_split_size, vl_interval, vl_margin, vl_thre):
    fig = plt.figure(figsize=(8, 6))
    raw_module.plot_peaks(n_list=[5, 8, 12], split_size=vl_split_size,
                          interval=vl_interval, margin=vl_margin, thre=vl_thre, direction=0)

inner_edges_para = {
    'vl_interval': widgets.IntText(value=40),
    'vl_thre': widgets.FloatText(value=0.9),
    'vl_split_size': widgets.IntText(value=20),
    'vl_margin': widgets.IntText(value=40)
}

interactive(update_edges, **inner_edges_para)
# Out:
# interactive(children=(IntText(value=20, description='vl_split_size'), IntText(value=40, description='vl_interv…

# %%
# Configuración de bordes horizontales

def update_edges(hl_split_size, hl_interval, hl_margin, hl_thre):
    fig = plt.figure(figsize=(8, 6))
    raw_module.plot_peaks(n_list=[5, 8, 12], split_size=hl_split_size,
                          interval=hl_interval, margin=hl_margin, thre=hl_thre, direction=1)

inner_edges_para = {
    'hl_interval': widgets.IntText(value=50),
    'hl_thre': widgets.FloatText(value=0.9),
    'hl_split_size': widgets.IntText(value=20),
    'hl_margin': widgets.IntText(value=20)
}

interactive(update_edges, **inner_edges_para)
# Out:
# interactive(children=(IntText(value=20, description='hl_split_size'), IntText(value=50, description='hl_interv…

# %%
# Recorte de celdas

single_cells = raw_module.crop_cell(32, plot=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Recorte de celdas
# ----> 3 single_cells = raw_module.crop_cell(32, plot=True)
#
# File ~/.local/lib/python3.10/site-packages/pv_vision/transform_crop/solarmodule.py:445, in MaskModule.crop_cell(self, cellsize, inner_edges_para, plot, simple)
#     443         if para not in inner_edges_para:
#     444             raise KeyError("{} is not provided.".format(para))
# --> 445 cells = self._transformed.crop_cell(cellsize=cellsize,
#     446                                     inner_edges_para=inner_edges_para,
#     447                                     plot=plot, simple=simple)
#     449 return cells
#
# File ~/.local/lib/python3.10/site-packages/pv_vision/transform_crop/solarmodule.py:536, in TransformedModule.crop_cell(self, cellsize, inner_edges_para, plot, simple)
#     533     else:
#     534         inner_edges_para = self.inner_edges_para
# --> 536 hline_abs_couple, vline_abs_couple = self._detect_inner_edges(cellsize, simple=simple,
#     537                                                               **inner_edges_para)
#     538 if plot:
#     539     self.plot_edges()
#
# File ~/.local/lib/python3.10/site-packages/pv_vision/transform_crop/solarmodule.py:504, in TransformedModule._detect_inner_edges(self, cellsize, vl_interval, vl_thre, vl_split_size, vl_margin, hl_interval, hl_thre, hl_split_size, hl_margin, simple)
#     501     hline_abs = list(zip(np.zeros(self.row - 1),
#     502                          np.linspace(0, self.size[0], self.row + 1)[1: -1].astype(int)))
#     503 else:
# --> 504     vinx_split, vline_split = seg.detect_edge(self._image, row_col=[self.row, self.col], cell_size=cellsize,
#     505                                               busbar=self.busbar, peaks_on=0, split_size=vl_split_size,
#     506                                               peak_interval=vl_interval, thre=vl_thre, margin=vl_margin)
#     507     vline_abs = seg.linear_regression(vinx_split, vline_split)
#     508     hinx_split, hline_split = seg.detect_edge(self._image, row_col=[self.row, self.col], cell_size=cellsize,
#     509                                               busbar=self.busbar, peaks_on=1, split_size=hl_split_size,
#     510                                               peak_interval=hl_interval, thre=hl_thre, margin=hl_margin)
#
# File ~/.local/lib/python3.10/site-packages/pv_vision/transform_crop/_cell_crop.py:578, in detect_edge(image, row_col, busbar, peaks_on, split_size, thre, cell_size, peak_interval, margin)
#     576     n_nan = np.argwhere(peaklist != 'nan')
#     577     for i in nan:
# --> 578         peaklist[int(i)] = peaklist[int(n_nan[0])]
#     579     peaklist = list(peaklist)
#     581 edgelist = np.array(list(zip(*peaklist)))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plt.imshow(single_cells[10], 'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.imshow(single_cells[10], 'gray')
#
# NameError: name 'single_cells' is not defined
